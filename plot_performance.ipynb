# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame(
    {
        "depth": [1, 5, 10, 15, 20, 25, 30, 50, 100],
        "bigWigCorrelate_score": [0.241869, 0.55027, 0.65792, 0.714053, 0.751173, 0.779792, 0.800911, 0.857043, 0.922172],
        # for i in 1 5 10 15 20 25 30 50 100; do bigWigCorrelate Sample_K562UNT_121109_proseq_1_QC.dREG.peak.score.bw Sample_K562UNT_121109_proseq_1_QC.${i}e6.dREG.peak.score.bw; done
        "bigWigCorrelate_prob": [0.18237, 0.433976, 0.537828, 0.597026, 0.637852, 0.671262, 0.696406, 0.767586, 0.864882],
        # for i in 1 5 10 15 20 25 30 50 100; do bigWigCorrelate Sample_K562UNT_121109_proseq_1_QC.dREG.peak.prob.bw Sample_K562UNT_121109_proseq_1_QC.${i}e6.dREG.peak.prob.bw; done
        "bigWigCorrelate_infp": [0.413018, 0.690644, 0.776733, 0.8211, 0.849792, 0.871523, 0.888223, 0.93004, 0.973239],
        "trogdor_prob": [0.415794, 0.559274, 0.626473, 0.667543, 0.696511, 0.720646, 0.741277, 0.803136, 0.900441],
        "jaccard": [0.0339778, 0.19266, 0.296479, 0.365348, 0.416916, 0.461303, 0.496258, 0.600893, 0.756212],
    }
)

# %%
#sns.relplot(x="depth", y="bigWigCorrelate_score", data=bigwig_comparison, kind="line")
sns.scatterplot(x="depth", y="bigWigCorrelate_score", data=data)
sns.scatterplot(x="depth", y="bigWigCorrelate_prob", data=data)
sns.scatterplot(x="depth", y="bigWigCorrelate_infp", data=data)
# Out:
# <Axes: xlabel='depth', ylabel='bigWigCorrelate_score'>

# %%
sns.scatterplot(x="depth", y="jaccard", data=data)
# Out:
# <Axes: xlabel='depth', ylabel='jaccard'>
